# %%
import pandas as pd
from pathlib import Path

# %%
df = pd.read_csv("crypto_data.csv")
df.head()
# Out:
#      Unnamed: 0        CoinName Algorithm  IsTrading ProofType  \
# 0            42         42 Coin    Scrypt       True   PoW/PoS
# 1           365         365Coin       X11       True   PoW/PoS
# 2           404         404Coin    Scrypt       True   PoW/PoS
# 3           611       SixEleven   SHA-256       True       PoW
# 4           808             808   SHA-256       True   PoW/PoS
# ...         ...             ...       ...        ...       ...
# 1247        XBC     BitcoinPlus    Scrypt       True       PoS
# 1248       DVTC      DivotyCoin    Scrypt      False   PoW/PoS
# 1249       GIOT     Giotto Coin    Scrypt      False   PoW/PoS
# 1250       OPSC  OpenSourceCoin   SHA-256      False   PoW/PoS
# 1251       PUNK       SteamPunk       PoS      False       PoS
#
#       TotalCoinsMined TotalCoinSupply
# 0        4.199995e+01              42
# 1                 NaN      2300000000
# 2        1.055185e+09       532000000
# 3                 NaN          611000
# 4        0.000000e+00               0
# ...               ...             ...
# 1247     1.283270e+05         1000000
# 1248     2.149121e+07       100000000
# 1249              NaN       233100000
# 1250              NaN        21000000
# 1251              NaN        40000000
#
# [1252 rows x 7 columns]

# %%
#filter out ones not trading
is_trading = df.loc[df["IsTrading"] == True]
is_trading["IsTrading"].value_counts()
# Out:
# True    1144
# Name: IsTrading, dtype: int64

# %%
df = is_trading.drop("IsTrading",axis=1)
df.head()
# Out:
#   Unnamed: 0   CoinName Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0         42    42 Coin    Scrypt   PoW/PoS     4.199995e+01              42
# 1        365    365Coin       X11   PoW/PoS              NaN      2300000000
# 2        404    404Coin    Scrypt   PoW/PoS     1.055185e+09       532000000
# 3        611  SixEleven   SHA-256       PoW              NaN          611000
# 4        808        808   SHA-256   PoW/PoS     0.000000e+00               0

# %%
#drop n/a's
df = df.dropna(how="any")
df.value_counts()
# Out:
# Unnamed: 0  CoinName      Algorithm           ProofType  TotalCoinsMined  TotalCoinSupply
# 1337        EliteCoin     X13                 PoW/PoS    2.927942e+10     314159265359       1
# PROC        ProCurrency   SHA-256             PoS        1.005457e+08     75000000000        1
# PNX         PhantomX      X11                 PoW/PoS    4.517421e+07     50000000           1
# PNY         Peony Coin    Scrypt              PoS        1.042012e+06     16880000000        1
# POA         Poa Network   Proof-of-Authority  PoA        2.044790e+08     252460800          1
#                                                                                             ..
# FJC         FujiCoin      Scrypt-n            PoW        0.000000e+00     10000000           1
# FLAP        Flappy Coin   Scrypt              PoW        0.000000e+00     100000000000       1
# FLDC        Folding Coin  Stanford Folding    PoW        7.194170e+08     1000000000         1
# FLIP        BitFlip       Scrypt              PoW        1.244610e+07     40000000           1
# ZYD         ZayedCoin     SHA-256             PoW        6.243840e+06     9736000            1
# Length: 685, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 685 entries, 0 to 1247
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       685 non-null    object
#  1   CoinName         685 non-null    object
#  2   Algorithm        685 non-null    object
#  3   ProofType        685 non-null    object
#  4   TotalCoinsMined  685 non-null    float64
#  5   TotalCoinSupply  685 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 37.5+ KB

# %%
#keep rows where the total coins mined is greater than zero
mined = df.loc[df["TotalCoinsMined"] > 0]
mined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 532 entries, 0 to 1247
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       532 non-null    object
#  1   CoinName         532 non-null    object
#  2   Algorithm        532 non-null    object
#  3   ProofType        532 non-null    object
#  4   TotalCoinsMined  532 non-null    float64
#  5   TotalCoinSupply  532 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 29.1+ KB

# %%
#drop the coin name column 
df.drop("CoinName", axis=1)
# Out:
#      Unnamed: 0    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0            42       Scrypt   PoW/PoS     4.199995e+01              42
# 2           404       Scrypt   PoW/PoS     1.055185e+09       532000000
# 4           808      SHA-256   PoW/PoS     0.000000e+00               0
# 5          1337          X13   PoW/PoS     2.927942e+10    314159265359
# 7           BTC      SHA-256       PoW     1.792718e+07        21000000
# ...         ...          ...       ...              ...             ...
# 1238       ZEPH      SHA-256      DPoS     2.000000e+09      2000000000
# 1242        GAP       Scrypt   PoW/PoS     1.493105e+07       250000000
# 1245        BDX  CryptoNight       PoW     9.802226e+08      1400222610
# 1246        ZEN     Equihash       PoW     7.296538e+06        21000000
# 1247        XBC       Scrypt       PoS     1.283270e+05         1000000
#
# [685 rows x 5 columns]

# %%
#create dummy columns for Algorithm
df = pd.get_dummies(df, columns=['Algorithm'],drop_first=True)
df.shape
# Out:
# (685, 84)

# %%
df.head()
# Out:
#      Unnamed: 0     CoinName ProofType  TotalCoinsMined TotalCoinSupply  \
# 0            42      42 Coin   PoW/PoS     4.199995e+01              42
# 2           404      404Coin   PoW/PoS     1.055185e+09       532000000
# 4           808          808   PoW/PoS     0.000000e+00               0
# 5          1337    EliteCoin   PoW/PoS     2.927942e+10    314159265359
# 7           BTC      Bitcoin       PoW     1.792718e+07        21000000
# ...         ...          ...       ...              ...             ...
# 1238       ZEPH       ZEPHYR      DPoS     2.000000e+09      2000000000
# 1242        GAP      Gapcoin   PoW/PoS     1.493105e+07       250000000
# 1245        BDX       Beldex       PoW     9.802226e+08      1400222610
# 1246        ZEN      Horizen       PoW     7.296538e+06        21000000
# 1247        XBC  BitcoinPlus       PoS     1.283270e+05         1000000
#
#       Algorithm_536  Algorithm_Argon2  Algorithm_Argon2d  Algorithm_BLAKE256  \
# 0                 0                 0                  0                   0
# 2                 0                 0                  0                   0
# 4                 0                 0                  0                   0
# 5                 0                 0                  0                   0
# 7                 0                 0                  0                   0
# ...             ...               ...                ...                 ...
# 1238              0                 0                  0                   0
# 1242              0                 0                  0                   0
# 1245              0                 0                  0                   0
# 1246              0                 0                  0                   0
# 1247              0                 0                  0                   0
#
#       Algorithm_Blake  ...  Algorithm_VeChainThor Authority  Algorithm_X11  \
# 0                   0  ...                                0              0
# 2                   0  ...                                0              0
# 4                   0  ...                                0              0
# 5                   0  ...                                0              0
# 7                   0  ...                                0              0
# ...               ...  ...                              ...            ...
# 1238                0  ...                                0              0
# 1242                0  ...                                0              0
# 1245                0  ...                                0              0
# 1246                0  ...                                0              0
# 1247                0  ...                                0              0
#
#       Algorithm_X11GOST  Algorithm_X13  Algorithm_X14  Algorithm_X15  \
# 0                     0              0              0              0
# 2                     0              0              0              0
# 4                     0              0              0              0
# 5                     0              1              0              0
# 7                     0              0              0              0
# ...                 ...            ...            ...            ...
# 1238                  0              0              0              0
# 1242                  0              0              0              0
# 1245                  0              0              0              0
# 1246                  0              0              0              0
# 1247                  0              0              0              0
#
#       Algorithm_X16R  Algorithm_XEVAN  Algorithm_Zhash  Algorithm_vDPOS
# 0                  0                0                0                0
# 2                  0                0                0                0
# 4                  0                0                0                0
# 5                  0                0                0                0
# 7                  0                0                0                0
# ...              ...              ...              ...              ...
# 1238               0                0                0                0
# 1242               0                0                0                0
# 1245               0                0                0                0
# 1246               0                0                0                0
# 1247               0                0                0                0
#
# [685 rows x 84 columns]

# %%
#create dummy columns for ProofType
df = pd.get_dummies(df, columns=['ProofType'],drop_first=True)
df.shape
# Out:
# (685, 109)

# %%
df.dtypes
# Out:
# Unnamed: 0                         object
# CoinName                           object
# TotalCoinsMined                   float64
# TotalCoinSupply                    object
# Algorithm_536                       uint8
#                                    ...
# ProofType_Proof of Authority        uint8
# ProofType_Proof of Trust            uint8
# ProofType_TPoS                      uint8
# ProofType_Zero-Knowledge Proof      uint8
# ProofType_dPoW/PoW                  uint8
# Length: 109, dtype: object

# %%
# Standardize your dataset so that columns that contain larger values do not unduly influence the outcome.
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
import numpy as np

df_scaled = StandardScaler().fit_transform(df)
print(df_scaled[0:5])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-f1f0ad4f55ff> in <module>
#       4 import numpy as np
#       5
# ----> 6 df_scaled = StandardScaler().fit_transform(df)
#       7 print(df_scaled[0:5])
#       8
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y, sample_weight)
#     728         # Reset internal state before fitting
#     729         self._reset()
# --> 730         return self.partial_fit(X, y, sample_weight)
#     731
#     732     def partial_fit(self, X, y=None, sample_weight=None):
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in partial_fit(self, X, y, sample_weight)
#     764         """
#     765         first_call = not hasattr(self, "n_samples_seen_")
# --> 766         X = self._validate_data(X, accept_sparse=('csr', 'csc'),
#     767                                 estimator=self, dtype=FLOAT_DTYPES,
#     768                                 force_all_finite='allow-nan', reset=first_call)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
#     420         elif isinstance(y, str) and y == 'no_validation':
# --> 421             X = check_array(X, **check_params)
#     422             out = X
#     423         else:
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     614                     array = array.astype(dtype, casting="unsafe", copy=False)
#     615                 else:
# --> 616                     array = np.asarray(array, order=order, dtype=dtype)
#     617             except ComplexWarning as complex_warning:
#     618                 raise ValueError("Complex data not supported\n"
#
# ~\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __array__(self, dtype)
#    1897
#    1898     def __array__(self, dtype=None) -> np.ndarray:
# -> 1899         return np.asarray(self._values, dtype=dtype)
#    1900
#    1901     def __array_wrap__(
#
# ~\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ValueError: could not convert string to float: 'BTC'

# %% [markdown]
# ### Perform dimensionality reduction with PCA
# Applying PCA to reduce dimensions and preserve 90% of explained variance

# %%
from sklearn.decomposition import PCA

# Initialize PCA model
pca = PCA(n_components=0.90)

df_pca = pca.fit_transform(df_scaled)

# %% [markdown]
# ### Further reduce the dataset dimensions with t-SNE
# In order to accomplish this task, run t-SNE on the principal components: the output of the PCA transformation.
# Then create a scatter plot of the t-SNE output.
# Observe whether there are distinct clusters or not.

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# Initialize t-SNE model
tsne = TSNE(learning_rate=35)


# Reduce dimensions
tsne_features = tsne.fit_transform(df2)

# Check the shape
tsne_features.shape

# %%
# Prepare to plot the dataset
#NOTE CHANGE ALL OF THE df2's to correct df


# The first column of transformed features
df2['x'] = tsne_features[:,0]

# The second column of transformed features
df2['y'] = tsne_features[:,1]

# %%
# Visualize the clusters
plt.scatter(df2['x'], df2['y'])
plt.show()

# %%
# Visualize the clusters
plt.scatter(df2['x'], df2['y'])
plt.show()

# Visualize the clusters with color
plt.scatter(df2['x'], df2['y'], c=labels)
plt.show()

# %% [markdown]
# ### Cluster Analysis with k-Means
# Create an elbow plot to identify the best number of clusters.
# Use a for-loop to determine the inertia for each `k` between 1 through 10.
# Determine where the elbow of the plot is, and at which value of `k` it appears.

# %%
from sklearn.cluster import KMeans
#Create an elbow plot to identify the best number of clusters. 

inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(df_shopping)
    inertia.append(km.inertia_)

# Create the Elbow Curve using hvPlot
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
df_elbow.head()

# %% [markdown]
# ### Elbow Curve

# %%
# Plot the elbow curve to find the best candidate(s) for k
plt.plot(df_elbow['k'], df_elbow['inertia'])
plt.xticks(range(1,11))
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.title('Elbow curve for customer data')
plt.show()

# %%
def get_clusters(k, data):
    # Initialize the K-Means model
    model = KMeans(n_clusters=k, random_state=0)

    # Train the model
    model.fit(data)

    # Predict clusters
    predictions = model.predict(data)

    # Create return DataFrame with predicted clusters
    data["class"] = model.labels_

    return data

# %% [markdown]
# ### Analyze clusters for best value of K

# %%
clusters = get_clusters(3, df_)
clusters

# %%
def show_clusters(df):
    plt.scatter(df['Annual Income'], df['Spending Score'], c=df['class'])
    plt.xlabel('Annual Income')
    plt.ylabel('Spending Score')
    plt.show()

# %%
show_clusters(clusters)
